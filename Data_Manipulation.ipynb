# %% [markdown]
# # KEY CONCEPTS
#
# **LIBRARIES:** Numpy (np) & Pandas (pd)
#
# ```
#
# 1.  Data Cleaning
#
# *   df.dropna(), df.fillna()
# *   df.drop_duplicates()
# *   df.replace()
#
# 2.  Merging and Reshaping Data
#
# *   pd.merge()
# *   df.pivot()
# *   df.melt()
#
# 3.  Grouping and Aggregation
#
# *   df.groupby()
# *   df.agg()
# ```

# %% [markdown]
# ## PANDAS EXERCISES (Beginner → Professional)

# %% [markdown]
# ### 🟢 LEVEL 1: Beginner (Core Data Handling)
#
# - Dataset Creation
#
# Use this sample dataset:
# ```
# import pandas as pd
#
# data = {
#     "Name": ["Ali", "Sara", "Ahmed", "Ayesha", "Bilal"],
#     "Age": [23, 25, 22, 24, 23],
#     "City": ["Karachi", "Lahore", "Karachi", "Islamabad", "Lahore"],
#     "Salary": [50000, 60000, 45000, 52000, 58000]
# }
#
# df = pd.DataFrame(data)
# ```

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Display first 3 rows

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ahmed", "Ayesha", "Bilal"],
    "Age": [23, 25, 22, 24, 23],
    "City": ["Karachi", "Lahore", "Karachi", "Islamabad", "Lahore"],
    "Salary": [50000, 60000, 45000, 52000, 58000]
}

df =pd.DataFrame(data)

df.head(3)
# Out:
#     Name  Age     City  Salary
# 0    Ali   23  Karachi   50000
# 1   Sara   25   Lahore   60000
# 2  Ahmed   22  Karachi   45000

# %% [markdown]
# #### 2. Get column names

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='object')

# %% [markdown]
# #### 3. Select only "Name" and "Salary"

# %%
df[['Name', 'Salary']]
# Out:
#      Name  Salary
# 0     Ali   50000
# 1    Sara   60000
# 2   Ahmed   45000
# 3  Ayesha   52000
# 4   Bilal   58000

# %% [markdown]
# #### 4. Filter people with Salary > 50000

# %%
df[df['Salary'] > 50000]
# Out:
#      Name  Age       City  Salary
# 1    Sara   25     Lahore   60000
# 3  Ayesha   24  Islamabad   52000
# 4   Bilal   23     Lahore   58000

# %% [markdown]
# #### 5. Add a new column Bonus = Salary * 0.1

# %%
df['Bonus'] = df['Salary'] * 0.1
df
# Out:
#      Name  Age       City  Salary   Bonus
# 0     Ali   23    Karachi   50000  5000.0
# 1    Sara   25     Lahore   60000  6000.0
# 2   Ahmed   22    Karachi   45000  4500.0
# 3  Ayesha   24  Islamabad   52000  5200.0
# 4   Bilal   23     Lahore   58000  5800.0

# %% [markdown]
# #### 6. Sort by Salary descending

# %%
df.sort_values('Salary',ascending=False)
# Out:
#      Name  Age       City  Salary   Bonus
# 1    Sara   25     Lahore   60000  6000.0
# 4   Bilal   23     Lahore   58000  5800.0
# 3  Ayesha   24  Islamabad   52000  5200.0
# 0     Ali   23    Karachi   50000  5000.0
# 2   Ahmed   22    Karachi   45000  4500.0

# %% [markdown]
# #### 7. Count how many people belong to each city

# %%
df['City'].value_counts()
# Out:
# City
# Karachi      2
# Lahore       2
# Islamabad    1
# Name: count, dtype: int64

# %% [markdown]
# ### 🟡 LEVEL 2: Data Cleaning (IMPORTANT 🔥)
# Dataset (Dirty Data)
# ```
# data = {
#     "Name": ["Ali", "Sara", "Ali", None, "Bilal"],
#     "Age": [23, None, 23, 24, 23],
#     "City": ["Karachi", "Lahore", "Karachi", "Islamabad", None],
#     "Salary": [50000, 60000, 50000, None, 58000]
# }
# df = pd.DataFrame(data)
# ```

# %% [markdown]
# ### Exercises (MANDATORY CONCEPTS)
#
# 👉 Goal: Clean dataset completely

# %% [markdown]
# #### 1. Identify missing values

# %%
data2 = {
    "Name": ["Ali", "Sara", "Ali", None, "Bilal"],
    "Age": [23, None, 23, 24, 23],
    "City": ["Karachi", "Lahore", "Karachi", "Islamabad", None],
    "Salary": [50000, 60000, 50000, None, 58000]
}
df2 = pd.DataFrame(data2)

df2.isna().sum()
# Out:
# Name      1
# Age       1
# City      1
# Salary    1
# dtype: int64

# %% [markdown]
# #### 2. Remove rows with missing values using:
# * `df.dropna()`

# %%
df2.dropna()
# Out:
#   Name   Age     City   Salary
# 0  Ali  23.0  Karachi  50000.0
# 2  Ali  23.0  Karachi  50000.0

# %% [markdown]
# #### 3. Fill missing values:
# * `Age → mean`
# * `City → "Unknown"`

# %%
df2['Age'].fillna(df2['Age'].mean())
# Out:
# 0    23.00
# 1    23.25
# 2    23.00
# 3    24.00
# 4    23.00
# Name: Age, dtype: float64

# %%
df2['City'].fillna('Unknown')
# Out:
# 0      Karachi
# 1       Lahore
# 2      Karachi
# 3    Islamabad
# 4      Unknown
# Name: City, dtype: object

# %% [markdown]
# #### 4. Remove duplicate rows:
# * `df.drop_duplicates()`

# %%
duplicate_values = df2.duplicated()
print(f"Duplicate values in DataFrame: {duplicate_values.sum()}")
# Out:
# Duplicate values in DataFrame: 1

# %%
df = df2.drop_duplicates()

# %%
df
# Out:
#     Name   Age       City   Salary
# 0    Ali  23.0    Karachi  50000.0
# 1   Sara   NaN     Lahore  60000.0
# 3   None  24.0  Islamabad      NaN
# 4  Bilal  23.0       None  58000.0

# %% [markdown]
# #### 5. Replace "Karachi" with "KHI":
# * `df.replace()`

# %%
df2.replace("Karachi","KHI")
# Out:
#     Name   Age       City   Salary
# 0    Ali  23.0        KHI  50000.0
# 1   Sara   NaN     Lahore  60000.0
# 2    Ali  23.0        KHI  50000.0
# 3   None  24.0  Islamabad      NaN
# 4  Bilal  23.0       None  58000.0

# %% [markdown]
# ### 🟠 LEVEL 3: Grouping & Aggregation

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Group by City and calculate:
# * `Average Salary`
# * `Max Salary`

# %%
df2.groupby('City')['Salary'].mean()
# Out:
# City
# Islamabad        NaN
# Karachi      50000.0
# Lahore       60000.0
# Name: Salary, dtype: float64

# %%
df2.groupby('City')['Salary'].max()
# Out:
# City
# Islamabad        NaN
# Karachi      50000.0
# Lahore       60000.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### 2. Use:
# * `df.groupby()`
# * `df.agg()`

# %%
df2.agg({'Age':'max', 'Salary':'mean'})
# Out:
# Age          24.0
# Salary    54500.0
# dtype: float64

# %% [markdown]
# #### 3. Find total salary per city

# %%
df2.groupby('City')['Salary'].sum()
# Out:
# City
# Islamabad         0.0
# Karachi      100000.0
# Lahore        60000.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### 4. Count employees per city

# %%
df2.groupby('City')['Name'].count()
# Out:
# City
# Islamabad    0
# Karachi      2
# Lahore       1
# Name: Name, dtype: int64

# %% [markdown]
# #### 5. Find highest paid person in each city

# %%
df_clean = df2.dropna(subset=['City', 'Salary'])

df_clean.loc[df_clean.groupby('City')['Salary'].idxmax()]
# Out:
#    Name   Age     City   Salary
# 0   Ali  23.0  Karachi  50000.0
# 1  Sara   NaN   Lahore  60000.0

# %% [markdown]
# ### 🔵 LEVEL 4: Merging & Reshaping Data
# Dataset
# ```
# df3 = pd.DataFrame({
#     "EmpID": [1, 2, 3],
#     "Name": ["Ali", "Sara", "Ahmed"]
# })
#
# df4 = pd.DataFrame({
#     "EmpID": [1, 2, 4],
#     "Salary": [50000, 60000, 70000]
# })
# ```

# %% [markdown]
# ### Exercises (MANDATORY CONCEPTS)

# %% [markdown]
# #### 🔹 Merging

# %% [markdown]
# ##### 1. Perform inner join using:
# * `pd.merge()`

# %%
# import pandas as pd

df3 = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Ali", "Sara", "Ahmed"]
})

df4 = pd.DataFrame({
    "EmpID": [1, 2, 4],
    "Salary": [50000, 60000, 70000]
})
# pd.merge(df3, df4, on="EmpID", how="inner") # how="inner" is default
pd.merge(df3, df4, on="EmpID")
# Out:
#    EmpID  Name  Salary
# 0      1   Ali   50000
# 1      2  Sara   60000

# %% [markdown]
# ##### 2. Perform left join

# %%
df5 = pd.merge(df3, df4, on="EmpID", how="outer")
df5
# Out:
#    EmpID   Name   Salary
# 0      1    Ali  50000.0
# 1      2   Sara  60000.0
# 2      3  Ahmed      NaN
# 3      4    NaN  70000.0

# %% [markdown]
# ##### 3. Identify missing matches

# %%
missing_matches = df5[df5['Name'].isna() | df5['Salary'].isna()]
print(f"The missing matches in the merged DataFrame are: \n{missing_matches}")
# Out:
# The missing matches in the merged DataFrame are:
#    EmpID   Name   Salary
# 2      3  Ahmed      NaN
# 3      4    NaN  70000.0

# %% [markdown]
# #### 🔹 Reshaping

# %% [markdown]
# ##### 4. Create pivot table:
# * `df.pivot(index='City', columns='Name', values='Salary')`

# %%
df.pivot(index='City', columns='Name', values='Salary')
# Out:
# Name       NaN      Ali    Bilal     Sara
# City
# NaN        NaN      NaN  58000.0      NaN
# Islamabad  NaN      NaN      NaN      NaN
# Karachi    NaN  50000.0      NaN      NaN
# Lahore     NaN      NaN      NaN  60000.0

# %% [markdown]
# ##### 5. Convert wide → long format:
# * `df.melt()`

# %%
df.melt(id_vars=['Name'], var_name='Category', value_name='Value')
# Out:
#      Name Category      Value
# 0     Ali      Age       23.0
# 1    Sara      Age        NaN
# 2    None      Age       24.0
# 3   Bilal      Age       23.0
# 4     Ali     City    Karachi
# 5    Sara     City     Lahore
# 6    None     City  Islamabad
# 7   Bilal     City       None
# 8     Ali   Salary    50000.0
# 9    Sara   Salary    60000.0
# 10   None   Salary        NaN
# 11  Bilal   Salary    58000.0

# %% [markdown]
# ###  🔴 LEVEL 5: Advanced Data Analysis

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Create a column:
# * `Salary Category (Low, Medium, High)`

# %%
df.loc[:,'Salary_Category'] = pd.qcut(df['Salary'], q=3, labels=['Low', 'Medium', 'High'])

# %%
df
# Out:
#     Name   Age       City   Salary Salary_Category
# 0    Ali  23.0    Karachi  50000.0             Low
# 1   Sara   NaN     Lahore  60000.0            High
# 3   None  24.0  Islamabad      NaN             NaN
# 4  Bilal  23.0       None  58000.0          Medium

# %% [markdown]
# #### 2. Apply custom function using apply()

# %%
df['Age_category'] = df['Age'].apply(lambda x: 'Young' if x < 25 else ('Middle_Aged' if x < 35 else 'Old'))
df
# Out:
# /tmp/ipykernel_6290/936774386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_category'] = df['Age'].apply(lambda x: 'Young' if x < 25 else ('Middle_Aged' if x < 35 else 'Old'))
#     Name   Age       City   Salary Salary_Category Age_category
# 0    Ali  23.0    Karachi  50000.0             Low        Young
# 1   Sara   NaN     Lahore  60000.0            High          Old
# 3   None  24.0  Islamabad      NaN             NaN        Young
# 4  Bilal  23.0       None  58000.0          Medium        Young

# %% [markdown]
# #### 3. Rank employees by salary

# %%
df['Salary_Rank'] = df['Salary'].rank(ascending=False)
df
# Out:
# /tmp/ipykernel_6290/2658610756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary_Rank'] = df['Salary'].rank(ascending=False)
#     Name   Age       City   Salary Salary_Category Age_category  Salary_Rank
# 0    Ali  23.0    Karachi  50000.0             Low        Young          3.0
# 1   Sara   NaN     Lahore  60000.0            High          Old          1.0
# 3   None  24.0  Islamabad      NaN             NaN        Young          NaN
# 4  Bilal  23.0       None  58000.0          Medium        Young          2.0

# %% [markdown]
# #### 4. Detect outliers using IQR

# %%
# Calculate Q1, Q3, and IQR
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outliers
filtered_df = df[(df['Salary'] >= lower_bound) & (df['Salary'] <= upper_bound)]

# %%
filtered_df
# Out:
#     Name   Age     City   Salary Salary_Category Age_category  Salary_Rank
# 0    Ali  23.0  Karachi  50000.0             Low        Young          3.0
# 1   Sara   NaN   Lahore  60000.0            High          Old          1.0
# 4  Bilal  23.0     None  58000.0          Medium        Young          2.0

# %% [markdown]
# #### 5. Normalize salary column
#
# ```
# # Min-Max Normalization (Scale to 0-1)
# (value - min) / (max - min)
# ```

# %%
# df['column_name'] = (df['column_name'] - df['column_name'].min()) / (df['column_name'].max() - df['column_name'].min())
df['Normalized_Salary'] = (df['Salary'] - df['Salary'].min()) / (df['Salary'].max() - df['Salary'].min())
df
# Out:
# /tmp/ipykernel_6290/1653831910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Normalized_Salary'] = (df['Salary'] - df['Salary'].min()) / (df['Salary'].max() - df['Salary'].min())
#     Name   Age       City   Salary Salary_Category Age_category  Salary_Rank  \
# 0    Ali  23.0    Karachi  50000.0             Low        Young          3.0
# 1   Sara   NaN     Lahore  60000.0            High          Old          1.0
# 3   None  24.0  Islamabad      NaN             NaN        Young          NaN
# 4  Bilal  23.0       None  58000.0          Medium        Young          2.0
#
#    Normalized_Salary
# 0                0.0
# 1                1.0
# 3                NaN
# 4                0.8

# %% [markdown]
# ### ⚫ LEVEL 6: Professional-Level Tasks

# %% [markdown]
# #### Real-world Mini Projects

# %% [markdown]
# ##### 🧩 Task 1: Sales Dataset
# * Clean dataset
# * Handle missing values
# * Group by region
# * Calculate revenue
#
# [Solved Task](https://colab.research.google.com/drive/1ydCzzuzdUjDW9L3Ju9ogDkcJ-zIJ-F31?usp=sharing)

# %% [markdown]
# ##### 🧩 Task 2: HR Analytics
# * Remove duplicates
# * Analyze attrition
# * Salary vs department analysis
#
# [Solved Task](https://colab.research.google.com/drive/1-UYzkJWFyzX0txSdNQtqjf6A6ngkdI11?usp=sharing)

# %% [markdown]
# ##### 🧩 Task 3: E-commerce
# * Top-selling products
# * Monthly sales trends
# * Customer segmentation
#
# [Solved Task](https://colab.research.google.com/drive/1lP9Z9RIQgLuqyypCaCF500IJgsb1Dokx?usp=sharing)

# %% [markdown]
# ## NUMPY EXERCISES (Beginner → Professional)

# %% [markdown]
# ### 🟢 LEVEL 1: Basics

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Create array of numbers 1–10

# %% [markdown]
# #### 2. Reshape into 2x5 matrix

# %% [markdown]
# #### 3. Find:
# * `Mean`
# * `Median`
# * `Standard deviation`

# %% [markdown]
# #### 4. Indexing:
# * `Get first row`
# * `Get last column`

# %% [markdown]
# ### 🟡 LEVEL 2: Array Operations

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Element-wise addition

# %% [markdown]
# #### 2. Multiply arrays

# %% [markdown]
# #### 3. Dot product

# %% [markdown]
# #### 4. Boolean filtering:
# * `Values > 5`

# %% [markdown]
# #### 5. Replace values:
# * `Replace all values > 5 with 100`

# %% [markdown]
# ### 🟠 LEVEL 3: Mathematical Operations

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Apply:
# * `np.log(), np.sqrt()`

# %% [markdown]
# #### 2. Normalize array

# %% [markdown]
# #### 3. Compute correlation between two arrays

# %% [markdown]
# #### 4. Generate random dataset:
# * `np.random.rand()`

# %% [markdown]
# ### 🔵 LEVEL 4: Advanced Indexing & Slicing

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Slice sub-matrix

# %% [markdown]
# #### 2. Use fancy indexing

# %% [markdown]
# #### 3. Modify specific rows/columns

# %% [markdown]
# #### 4. Find indices of values > threshold

# %% [markdown]
# ### 🔴 LEVEL 5: Linear Algebra (Professional 🔥)

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 1. Matrix multiplication

# %% [markdown]
# #### 2. Determinant

# %% [markdown]
# #### 3. Inverse

# %% [markdown]
# #### 4. Eigenvalues & eigenvectors

# %% [markdown]
# ### ⚫ LEVEL 6: Real-world Use Cases

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### 🧩 Task 1: Image Processing
# * Convert image to numpy array
# * Normalize pixel values

# %% [markdown]
# #### 🧩 Task 2: Data Simulation
# * Generate dataset (1000 rows)
# * Add noise
# * Analyze distribution

# %% [markdown]
# #### 🧩 Task 3: Performance Optimization
# * Compare Python list vs NumPy speed

# %% [markdown]
# ### COMBINED PANDAS + NUMPY PROJECTS (Coming Next)
# * End-to-end Data Science workflows
# * Kaggle-style datasets
# * ML preprocessing pipelines
